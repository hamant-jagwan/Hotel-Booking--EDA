# %% [markdown]
# <a href="https://colab.research.google.com/github/hamant-jagwan/Hotel-Booking--EDA/blob/main/hotel_booking_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FIRST VIEW OF DATASET

# %% [markdown]
# importing libraires

# %%
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# configuration
pd.set_option('display.max_columns', None) #sets the maximum number of columns to be displayed when printing a Pandas DataFrame

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/data/hotel_booking.csv'
hb_df = pd.read_csv(file_path)

# %% [markdown]
# ## DATA FIRST VIEW

# %%
hb_df.head(5) # view of hotel booking data
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
hb_df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# removing last 4 columns because it is not neccesary for analysis  and contain personal information
hb_df = hb_df.iloc[:,:-4]

# %%
hb_df.shape
# Out:
# (119390, 32)

# %%
hb_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
hb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# This user define function will give the type,count of null and non null values as well as null ratio
def hotelbookinginfo():
  temp=pd.DataFrame(index=hb_df.columns)
  temp["datatype"]=hb_df.dtypes
  temp["not null values"]=hb_df.count()
  temp["null value"]=hb_df.isnull().sum()
  temp["% of the null value"]=hb_df.isnull().mean()*100
  temp["unique count"]=hb_df.nunique() # Return Series with number of distinct elements. Can ignore NaN values.
  return temp
hotelbookinginfo()
# Out:
#                                datatype  not null values  null value  \
# hotel                            object           119390           0
# is_canceled                       int64           119390           0
# lead_time                         int64           119390           0
# arrival_date_year                 int64           119390           0
# arrival_date_month               object           119390           0
# arrival_date_week_number          int64           119390           0
# arrival_date_day_of_month         int64           119390           0
# stays_in_weekend_nights           int64           119390           0
# stays_in_week_nights              int64           119390           0
# adults                            int64           119390           0
# children                        float64           119386           4
# babies                            int64           119390           0
# meal                             object           119390           0
# ...

# %% [markdown]
# The columns and the data it represents are listed below:
#
# **1. hotel :** Name of the hotel (Resort Hotel or City Hotel)
#
# **2. is_canceled :** If the booking was canceled (1) or not (0)
#
# **3. lead_time :** Number of days before the actual arrival of the guests
#
# **4. arrival_date_year :** Year of arrival date
#
# **5. arrival_date_month :** Month of month arrival date
#
# **6. arrival_date_week_number :** Week number of year for arrival date
#
# **7. arrival_date_day_of_month :** Day of arrival date
#
# **8. stays_in_weekend_nights :** Number of weekend nights (Saturday or Sunday) spent at the hotel by the guests.
#
# **9. stays_in_week_nights :** Number of weeknights (Monday to Friday) spent at the hotel by the guests.
#
# **10. adults :** Number of adults among guests
#
# **11. children :** Number of children among guests
#
# **12. babies :** Number of babies among guests
#
# **13. meal :** Type of meal booked
#
# **14. country :** Country of guests
#
# **15. market_segment :** Designation of market segment
#
# **16. distribution_channel :** Name of booking distribution channel
#
# **17. is_repeated_guest :** If the booking was from a repeated guest (1) or not (0)
#
# **18. previous_cancellations :** Number of previous bookings that were cancelled by the customer prior to the current booking
#
# **19. previous_bookings_not_canceled :** Number of previous bookings not cancelled by the customer prior to the current booking
#
# **20. reserved_room_type :** Code of room type reserved
#
# **21. assigned_room_type :** Code of room type assigned
#
# **22. booking_changes :** Number of changes/amendments made to the booking
#
# **23. deposit_type :** Type of the deposit made by the guest
#
# **24. agent :** ID of travel agent who made the booking
#
# **25. company :** ID of the company that made the booking
#
# **26. days_in_waiting_list :** Number of days the booking was in the waiting list
#
# **27. customer_type :** Type of customer, assuming one of four categories
#
# **28. adr :** Average Daily Rate, as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# **29. required_car_parking_spaces :** Number of car parking spaces required by the customer
#
# **30. total_of_special_requests :** Number of special requests made by the customer
#
# **31. reservation_status :** Reservation status (Canceled, Check-Out or No-Show)
#
# **32. reservation_status_date :** Date at which the last reservation status was updated

# %%
# converting the `reservation_status_date` into datetime datatype

hb_df['reservation_status_date'] = pd.to_datetime(hb_df['reservation_status_date'])

# %%
hb_df.describe(include = 'object').T
# Out:
#                        count unique         top    freq
# hotel                 119390      2  City Hotel   79330
# arrival_date_month    119390     12      August   13877
# meal                  119390      5          BB   92310
# country               118902    177         PRT   48590
# market_segment        119390      8   Online TA   56477
# distribution_channel  119390      5       TA/TO   97870
# reserved_room_type    119390     10           A   85994
# assigned_room_type    119390     12           A   74053
# deposit_type          119390      3  No Deposit  104641
# customer_type         119390      4   Transient   89613
# reservation_status    119390      3   Check-Out   75166

# %%
for col in hb_df.describe(include = 'object').columns:
  print(col)

  print(hb_df[col].unique())
  print("-" *80)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
# ...

# %%
hb_df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
hb_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# In the above data we have four columns that have null values and these columns are the following
#
# 1. `children`  = 4
# 2. `country`   = 488
# 3. `agent`     = 16340
# 4. `company`   = 112593
#
# * There are some missing values in the `children` and `country` fields. We can safely remove these values from the dataset.
#
# * We can remove the `agent` and `company` columns due to excessive null values, as they are not necessary for our analysis.

# %%
hb_df.drop(['company', 'agent'], axis = 1 , inplace = True) #In order to remove a column, it is imperative to specify axis=1.
hb_df.dropna(inplace = True)

# %%
# checking the value
hb_df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
hb_df.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     118898.0     0.371352    0.483168     0.00
# lead_time                       118898.0   104.311435  106.903309     0.00
# arrival_date_year               118898.0  2016.157656    0.707459  2015.00
# arrival_date_week_number        118898.0    27.166555   13.589971     1.00
# arrival_date_day_of_month       118898.0    15.800880    8.780324     1.00
# stays_in_weekend_nights         118898.0     0.928897    0.996216     0.00
# stays_in_week_nights            118898.0     2.502145    1.900168     0.00
# adults                          118898.0     1.858391    0.578576     0.00
# children                        118898.0     0.104207    0.399172     0.00
# babies                          118898.0     0.007948    0.097380     0.00
# is_repeated_guest               118898.0     0.032011    0.176029     0.00
# ...

# %% [markdown]
# In above data, we can see the `adr` column having a max value of 5400 and it is showing an outlier

# %%
hb_df =hb_df[hb_df['adr']< 5000]

# %% [markdown]
# # **Data Analysis and Visualizations**

# %% [markdown]
# ### **Visualization of  `is_canceled` column**

# %%
cancelled_perc = hb_df['is_canceled'].value_counts(normalize = True)*100
cancelled_perc
# Out:
# 0    62.865337
# 1    37.134663
# Name: is_canceled, dtype: float64

# %%
plt.figure(figsize = (4,4))
plt.title("Reservation status count")

plt.pie(cancelled_perc, autopct='%.0f%%');
plt.legend(labels= ["Not cancelled", "cancelled"] )
plt.show()

# %%
plt.figure(figsize = (8,4))
ax1 = sns.countplot(x = 'hotel', hue = 'is_canceled', data = hb_df, palette='Blues')
plt.legend(labels= ["Not cancelled", "cancelled"])

plt.title('Reservation status in different hotels', size = 20)
plt.xlabel('hotel')
plt.ylabel('number of reservation')
plt.show()

# %%
resort_hotel= hb_df[hb_df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)*100
# Out:
# 0    72.024952
# 1    27.975048
# Name: is_canceled, dtype: float64

# %%
city_hotel = hb_df[hb_df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)*100
# Out:
# 0    58.291825
# 1    41.708175
# Name: is_canceled, dtype: float64

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize = (20, 8))
plt.title('Average Daily Rate in City and Resort Hotel', fontsize = 30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label = "Resort Hotel")
plt.plot(city_hotel.index, city_hotel['adr'], label = "city Hotel")
plt.legend(fontsize = 20)
plt.show()

# %%
hb_df['month'] = hb_df['reservation_status_date'].dt.month
plt.figure(figsize= (12,6))
ax1 = sns.countplot(x = 'month', hue = 'is_canceled', data  =hb_df )
plt.title('Reservation status per month', size = 20)
plt.xlabel('month')
plt.ylabel('number of reservations')
plt.legend(['not canceled', 'canceled'])
plt.show()

# %%
month_wise_1 = hb_df[hb_df['is_canceled'] == 1].groupby('month')
value_1_12 = month_wise_1['adr'].sum().reset_index()
value_1_12
# Out:
#     month        adr
# 0       1  571203.57
# 1       2  447675.76
# 2       3  424872.56
# 3       4  425315.23
# 4       5  391438.08
# 5       6  359003.34
# 6       7  481376.17
# 7       8  325668.43
# 8       9  274176.33
# 9      10  330968.87
# 10     11  281367.90
# 11     12  319272.65

# %%
plt.figure(figsize= (15,8))
plt.title('ADR per month', fontsize = 30)
sns.barplot(  data =  value_1_12, x = 'month', y = 'adr')

plt.show();

# %%
#fetching  top 10 countries which have cancelled  most hotel bookings
cancelled_data = hb_df[hb_df['is_canceled']==1]
top_10_country = cancelled_data['country'].value_counts()[:10]
top_10_country
# Out:
# PRT    27514
# GBR     2453
# ESP     2177
# FRA     1934
# ITA     1333
# DEU     1218
# IRL      832
# BRA      830
# USA      501
# BEL      474
# Name: country, dtype: int64

# %%
plt.figure(figsize = (10, 10))
plt.pie(top_10_country,  autopct = '%.2f' , labels = top_10_country.index)
plt.title('Top 10 countries with reservation canceled',fontdict = {'fontsize': 20} )
plt.show()

# %%
hb_df['market_segment'].value_counts(normalize= True)*100
# Out:
# Online TA        47.437698
# Offline TA/TO    20.319268
# Groups           16.658116
# Direct           10.469566
# Corporate         4.298679
# Complementary     0.617341
# Aviation          0.199332
# Name: market_segment, dtype: float64

# %%
cancelled_df_adr = hb_df[hb_df['is_canceled'] == 1].groupby('reservation_status_date')
cancelled_df_adr = cancelled_df_adr['adr'].mean().reset_index()
cancelled_df_adr.sort_values('reservation_status_date', inplace = True)



not_cancelled_data = hb_df[hb_df['is_canceled']== 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')['adr'].mean()
not_cancelled_df_adr=  not_cancelled_df_adr.reset_index()
not_cancelled_df_adr.sort_values('reservation_status_date', inplace = True)

# %%
cancelled_df_adr
# Out:
#     reservation_status_date         adr
# 0                2014-10-17   62.800000
# 1                2014-11-18    0.000000
# 2                2015-01-01   62.062779
# 3                2015-01-02    9.633750
# 4                2015-01-18    0.000000
# ..                      ...         ...
# 897              2017-08-26  178.200000
# 898              2017-08-27  167.300000
# 899              2017-08-28   81.416667
# 900              2017-08-29  144.253333
# 901              2017-08-31  189.750000
#
# [902 rows x 2 columns]

# %%
not_cancelled_df_adr
# Out:
#     reservation_status_date         adr
# 0                2015-07-01   31.650000
# 1                2015-07-02   95.924000
# 2                2015-07-03   97.645205
# 3                2015-07-04  110.480000
# 4                2015-07-05  100.308485
# ..                      ...         ...
# 800              2017-09-08  101.012500
# 801              2017-09-09  147.778333
# 802              2017-09-10  145.272500
# 803              2017-09-12  153.570000
# 804              2017-09-14  105.930000
#
# [805 rows x 2 columns]

# %%
plt.figure(figsize = (20,6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label = 'not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label  = 'cancelled')
plt.legend()
plt.show()

# %%
cancelled_df_adr = cancelled_df_adr[(cancelled_df_adr['reservation_status_date'] > '2016') & (cancelled_df_adr['reservation_status_date'] < '2017-09')]
not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date'] > '2016') & (not_cancelled_df_adr['reservation_status_date']< '2017-09')]

# %%
plt.figure(figsize = (20, 6))
plt.title('Average Daily Rate', fontsize  = 30)
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label = 'not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'] , label = 'cancelled')
plt.legend(fontsize = 20)
plt.show()
